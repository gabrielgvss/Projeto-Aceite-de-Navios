# %%
#IMPORTANDO BIBLIOTECAS
import numpy as np
import pandas as pd
import random

# %%
# INTERVALOS DE VALORES PARA OS CAMPOS
loa_min = 15
loa_max = 60

boca_min = 6
boca_max = 18

dwt_min = 30000
dwt_max = 200000

calado_entrada_min = 8
calado_entrada_max = 20

calado_saida_min = 8
calado_saida_max = 20

calado_aereo_min = 10
calado_aereo_max = 35

pontal_min = 5
pontal_max = 20

tamanho_lanca_min = 10
tamanho_lanca_max = 120

ano_construcao_min = 1990
ano_construcao_max = 2023

tipos_navio = ['GS', 'CG', 'GSM', 'GL', 'GLP', 'CNTR']

# %%
# NUMERO DE AMOSTRAS QUE SERÃO GERADAS
num_amostras = 1000

# GERAÇÃO DE VALORES ALEATÓRIOS VIA NUMPY
np.random.seed(0)
random.seed(0)

nomes = np.array(['Navio' + str(i) for i in range(1, num_amostras + 1)])

loa = np.random.randint(loa_min, loa_max, num_amostras)

boca = np.random.randint(boca_min, boca_max, num_amostras)

dwt = np.random.randint(dwt_min, dwt_max, num_amostras)

calado_entrada = np.random.randint(calado_entrada_min, calado_entrada_max, num_amostras)

calado_saida = np.random.randint(calado_saida_min, calado_saida_max, num_amostras)

calado_aereo = np.random.randint(calado_aereo_min, calado_aereo_max, num_amostras)

pontal = np.random.randint(pontal_min, pontal_max, num_amostras)

tamanho_lanca = np.random.randint(tamanho_lanca_min, tamanho_lanca_max, num_amostras)

ano_construcao = np.random.randint(ano_construcao_min, ano_construcao_max, num_amostras)

ultimo_porto = np.array(['Porto' + str(i) for i in np.random.randint(1, 6, num_amostras)])

proximo_porto = np.array(['Porto' + str(i) for i in np.random.randint(1, 6, num_amostras)])

tipo_navio = [random.choice(tipos_navio) for _ in range(num_amostras)]

# %%
#CRIAÇÃO DE DATAFRAME COM VALORES
data = {
    'Nome': nomes,
    'LOA (m)': loa,
    'Boca (m)': boca,
    'DWT (ton)': dwt,
    'Calado de Entrada (m)': calado_entrada,
    'Calado de Saída (m)': calado_saida,
    'Calado Aéreo (m)': calado_aereo,
    'Pontal (m)': pontal,
    'Tamanho de Lança (m)': tamanho_lanca,
    'Ano de Construção': ano_construcao,
    'Tipo do Navio': tipo_navio,
    'Último Porto': ultimo_porto,
    'Próximo Porto': proximo_porto

}

df = pd.DataFrame(data)

# %%
#CRIACAO DE CONDICOES PARA DETERMINAÇÃO DA CLASSE DE ACORDO COM PREVISORES
def determinar_classificacao(df):
    condicao_loa = df['LOA (m)'] <= 280
    condicao_boca = df['Boca (m)'] <= 50
    condicao_dwt = df['DWT (ton)'] <= 155000
    condicao_ce = df['Calado de Entrada (m)'] <= 18.5
    condicao_cs = df['Calado de Saída (m)'] <= 18.5
    condicao_idade = 2023 - df['Ano de Construção'] < 18

    combinacao = condicao_loa and condicao_boca and condicao_dwt and condicao_ce and condicao_cs and condicao_idade
    return 1 if combinacao else 0

# %%
#CRIACAO DA CLASSE 'SITUACAO' 0 - NEGADO, 1 - APROVADO
df['Situação'] = df.apply(determinar_classificacao, axis=1)
df.head(30)
# Out:
#        Nome  LOA (m)  Boca (m)  DWT (ton)  Calado de Entrada (m)  \
# 0    Navio1       59        15      63260                     14
# 1    Navio2       15         9      46723                     13
# 2    Navio3       18        11     191817                     15
# 3    Navio4       18        13     195241                     11
# 4    Navio5       54        17      37299                     10
# 5    Navio6       24        15     161956                     16
# 6    Navio7       34        17      69892                      9
# 7    Navio8       36         6      34081                     11
# 8    Navio9       51        17      30851                     16
# 9   Navio10       38        13     114217                     19
# 10  Navio11       21        17      32597                     11
# 11  Navio12       39         7     145564                     19
# 12  Navio13       39         8      74761                     13
# 13  Navio14       27        11      88887                      9
# 14  Navio15       16         6      82156                     10
# 15  Navio16       53        11     191957                     18
# 16  Navio17       54        14      45956                     19
# 17  Navio18       38        15      86314                     19
# 18  Navio19       39        14     192064                     14
# 19  Navio20       32         8     162584                     11
# 20  Navio21       52        17     152023                     10
# 21  Navio22       40        11     119953                     13
# 22  Navio23       28         9      56433                     11
# 23  Navio24       23         7      85497                     13
# 24  Navio25       24        13      52615                     19
# 25  Navio26       35         9      68212                      9
# 26  Navio27       31        16     186678                     17
# 27  Navio28       20        14      87185                     18
# 28  Navio29       30        11      64162                      9
# 29  Navio30       15        16     172908                     18
#
#     Calado de Saída (m)  Calado Aéreo (m)  Pontal (m)  Tamanho de Lança (m)  \
# 0                     8                24          19                    11
# 1                    15                30          13                    60
# 2                    16                28          10                    33
# 3                    16                19          12                    74
# 4                    15                16          14                    24
# 5                    12                14          18                   101
# 6                    18                21           8                    87
# 7                    14                27          10                    47
# 8                    17                10          16                    62
# 9                    14                21          15                   108
# 10                   16                33          17                    86
# 11                   11                34           5                    12
# 12                   15                28           8                   107
# 13                   16                18          18                    88
# 14                   12                31          16                    27
# 15                   10                29           5                   115
# 16                   11                12          13                    54
# 17                    8                28           9                    81
# 18                   12                16          19                    37
# 19                   16                34          13                    33
# 20                    8                24           8                   109
# 21                   19                21           5                    75
# 22                   18                11          14                    81
# 23                   12                30          11                    67
# 24                   10                23           8                    85
# 25                   14                23          15                    67
# 26                   10                11          17                   113
# 27                   10                20           8                    20
# 28                   10                29           5                    18
# 29                   15                33          11                    24
#
#     Ano de Construção Tipo do Navio Último Porto Próximo Porto  Situação
# 0                2000            GL       Porto5        Porto5         0
# 1                2001            GL       Porto3        Porto3         0
# 2                1994            GS       Porto5        Porto1         0
# 3                2007           GSM       Porto5        Porto5         0
# 4                1994           GLP       Porto2        Porto2         0
# 5                2016            GL       Porto3        Porto4         0
# 6                1997            GL       Porto5        Porto4         0
# 7                1992           GSM       Porto5        Porto3         0
# 8                2010            GL       Porto3        Porto5         1
# 9                2019           GSM       Porto3        Porto2         0
# 10               1992           GLP       Porto3        Porto2         0
# 11               2004            CG       Porto4        Porto5         0
# 12               2000           GLP       Porto3        Porto5         0
# 13               2002            CG       Porto2        Porto1         0
# 14               2016           GSM       Porto1        Porto4         1
# 15               2004            CG       Porto5        Porto5         0
# 16               2020            GS       Porto3        Porto5         0
# 17               1993           GLP       Porto4        Porto2         0
# 18               2004           GSM       Porto5        Porto3         0
# 19               2011           GLP       Porto5        Porto4         0
# 20               1995          CNTR       Porto2        Porto4         0
# 21               2006           GLP       Porto4        Porto4         0
# 22               1997            CG       Porto5        Porto1         0
# 23               2010           GSM       Porto2        Porto4         1
# 24               2009            GS       Porto4        Porto2         0
# 25               1992          CNTR       Porto4        Porto5         0
# 26               2022            GS       Porto3        Porto2         0
# 27               2008          CNTR       Porto4        Porto1         1
# 28               2007           GSM       Porto2        Porto1         1
# 29               1992            GL       Porto4        Porto2         0

# %%
df = df.to_csv('dados_simulacao.csv', index=False)
